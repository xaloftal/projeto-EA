# %%
import pandas as pd

# %%
df_bus = pd.read_csv('data/BusStopList.csv')
df_oct = pd.read_csv('data/BUS_DATA_OCT_2017.csv')

# %%
df_oct.columns
# Out:
# Index(['Card_Number', 'Card_Type', 'Travel_Mode', 'Bus_Service_Number',
#        'Direction', 'Bus_Trip_Num', 'Bus_Reg_Num', 'Boarding_stop_stn',
#        'Alighting_stop_stn', 'Ride_start_date', 'Ride_start_time',
#        'Ride_end_date', 'Ride_end_time'],
#       dtype='str')

# %%
df_oct.head()
# Out:
#    Card_Number Card_Type Travel_Mode Bus_Service_Number Direction  \
# 0            0         A         Bus           SER_1253     Start
# 1            1         A         Bus           SER_dccb     Start
# 2            2         A         Bus           SER_dccb     Start
# 3            3         A         Bus           SER_61a2    Return
# 4            4         A         Bus           SER_1253     Start
#
#   Bus_Trip_Num Bus_Reg_Num Boarding_stop_stn Alighting_stop_stn  \
# 0    TRIP_7b1b    REG_4caf              IU_1              AGV_1
# 1    TRIP_2b71    REG_88ec             ELY_1                I_4
# 2    TRIP_5853    REG_cca4              MH_2              ELY_1
# 3    TRIP_8ab3    REG_1fb5              IU_1              CYS_1
# 4    TRIP_d84b    REG_5e11              IU_1               EU_2
#
#   Ride_start_date Ride_start_time Ride_end_date Ride_end_time
# 0      2017-10-28        21:32:41    2017-10-28      21:35:21
# ...

# %%
# check the different vlalues of columns Card_Type, Travel_Mode, Bus_Service_Number

cols = ['Card_Type', 'Travel_Mode', 'Bus_Service_Number', 'Bus_Reg_Num', 'Alighting_stop_stn', 'Boarding_stop_stn']
for col in cols:
    print(f"Column: {col}")
    print(df_oct[col].value_counts(dropna=False))
    print("-" * 50)
# Out:
# Column: Card_Type
# Card_Type
# A     82472496
# SC    17629796
# S     11292079
# C      1178129
# Name: count, dtype: int64
# --------------------------------------------------
# Column: Travel_Mode
# Travel_Mode
# Bus    112572500
# Name: count, dtype: int64
# --------------------------------------------------
# Column: Bus_Service_Number
# Bus_Service_Number
# SER_1d28    1118863
# SER_8b94    1102309
# SER_49d1    1005644
# SER_108c     932944
# SER_8722     903013
#              ...
# SER_5138          5
# SER_d179          3
# SER_3cad          3
# SER_7022          2
# SER_12f2          2
# Name: count, Length: 555, dtype: int64
# --------------------------------------------------
# Column: Bus_Reg_Num
# Bus_Reg_Num
# REG_99eb    124210
# REG_7e37    112098
# REG_f957    103337
# REG_c950     99127
# REG_1da9     95398
#              ...
# REG_2f55         5
# REG_6747         5
# REG_f12b         5
# REG_1093         4
# REG_cf05         1
# ...
